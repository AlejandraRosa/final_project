# %%
# Dependencies

import pandas as pd

# %%
#https://www.kaggle.com/tinoswe/split-python-dataframe
title_basics = pd.read_csv('../data/title.basics.tsv',delimiter='\t',encoding='utf-8-sig')
# Out:
# C:\Users\alerosa\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(list(title_basics.columns.values))
# Out:
# ['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes', 'genres']

# %%
title_basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 6751895  tt9916848  tvEpisode              Episode #3.17
# 6751896  tt9916850  tvEpisode              Episode #3.19
# 6751897  tt9916852  tvEpisode              Episode #3.20
# 6751898  tt9916856      short                   The Wind
# 6751899  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita        0      1894      \N              1
# 1           Le clown et ses chiens        0      1892      \N              5
# 2                   Pauvre Pierrot        0      1892      \N              4
# 3                      Un bon bock        0      1892      \N             12
# 4                 Blacksmith Scene        0      1893      \N              1
# ...                            ...      ...       ...     ...            ...
# 6751895              Episode #3.17        0      2010      \N             \N
# 6751896              Episode #3.19        0      2010      \N             \N
# 6751897              Episode #3.20        0      2010      \N             \N
# 6751898                   The Wind        0      2015      \N             27
# 6751899  Horrid Henry Knows It All        0      2014      \N             10
#
#                            genres
# 0               Documentary,Short
# 1                 Animation,Short
# 2        Animation,Comedy,Romance
# 3                 Animation,Short
# 4                    Comedy,Short
# ...                           ...
# 6751895       Action,Drama,Family
# 6751896       Action,Drama,Family
# 6751897       Action,Drama,Family
# 6751898                     Short
# 6751899   Animation,Comedy,Family
#
# [6751900 rows x 9 columns]

# %%
title_basics_filtered = title_basics[title_basics['titleType']!="tvEpisode"]
title_basics_filtered.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
title_basics_filtered.count
# Out:
# <bound method DataFrame.count of             tconst titleType                    primaryTitle  \
# 0        tt0000001     short                      Carmencita
# 1        tt0000002     short          Le clown et ses chiens
# 2        tt0000003     short                  Pauvre Pierrot
# 3        tt0000004     short                     Un bon bock
# 4        tt0000005     short                Blacksmith Scene
# ...            ...       ...                             ...
# 6751841  tt9916734     video                    Manca: Peleo
# 6751850  tt9916754     movie  Chico Albuquerque - Revelações
# 6751851  tt9916756     short        Pretty Pretty Black Girl
# 6751855  tt9916764     short                              38
# 6751898  tt9916856     short                        The Wind
#
#                           originalTitle  isAdult startYear endYear  \
# 0                            Carmencita        0      1894      \N
# 1                Le clown et ses chiens        0      1892      \N
# 2                        Pauvre Pierrot        0      1892      \N
# 3                           Un bon bock        0      1892      \N
# 4                      Blacksmith Scene        0      1893      \N
# ...                                 ...      ...       ...     ...
# 6751841                    Manca: Peleo        0      2018      \N
# 6751850  Chico Albuquerque - Revelações        0      2013      \N
# 6751851        Pretty Pretty Black Girl        0      2019      \N
# 6751855                              38        0      2018      \N
# 6751898                        The Wind        0      2015      \N
#
#         runtimeMinutes                    genres
# 0                    1         Documentary,Short
# 1                    5           Animation,Short
# 2                    4  Animation,Comedy,Romance
# 3                   12           Animation,Short
# 4                    1              Comedy,Short
# ...                ...                       ...
# 6751841             \N               Music,Short
# 6751850             49               Documentary
# 6751851             \N                     Short
# 6751855             \N                     Short
# 6751898             27                     Short
#
# [1948514 rows x 9 columns]>

# %%
title_ratings = pd.read_csv('../data/title.ratings.tsv',delimiter='\t',encoding='utf-8-sig')

# %%
title_ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1609
# 1        tt0000002            6.0       197
# 2        tt0000003            6.5      1287
# 3        tt0000004            6.1       121
# 4        tt0000005            6.1      2052
# ...            ...            ...       ...
# 1031803  tt9916576            6.0         9
# 1031804  tt9916578            8.4        17
# 1031805  tt9916720            5.6        49
# 1031806  tt9916766            6.8        13
# 1031807  tt9916778            7.2        21
#
# [1031808 rows x 3 columns]

# %%
title_crew = pd.read_csv('../data/title.crew.tsv',delimiter='\t',encoding='utf-8-sig')

# %%
title_crew
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 6751895  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 6751896  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 6751897  tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377
# 6751898  tt9916856           nm10538645                      nm6951431
# 6751899  tt9916880            nm0996406            nm1482639,nm2586970
#
# [6751900 rows x 3 columns]

# %%
name_basics = pd.read_csv('../data/name.basics.tsv',delimiter='\t',encoding='utf-8-sig')

# %%
name_basics
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 10046386  nm9993714   Romeo del Rosario        \N        \N
# 10046387  nm9993716       Essias Loberg        \N        \N
# 10046388  nm9993717  Harikrishnan Rajan        \N        \N
# 10046389  nm9993718         Aayush Nair        \N        \N
# 10046390  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2                 actress,soundtrack,producer
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 10046386  animation_department,art_department
# 10046387                                  NaN
# 10046388                      cinematographer
# 10046389                      cinematographer
# 10046390                                  NaN
#
#                                    knownForTitles
# 0         tt0072308,tt0043044,tt0050419,tt0053137
# 1         tt0117057,tt0037382,tt0071877,tt0038355
# 2         tt0049189,tt0054452,tt0057345,tt0059956
# 3         tt0077975,tt0072562,tt0078723,tt0080455
# 4         tt0050976,tt0083922,tt0060827,tt0050986
# ...                                           ...
# 10046386                                tt2455546
# 10046387                                       \N
# 10046388                                tt8736744
# 10046389                                       \N
# 10046390                                       \N
#
# [10046391 rows x 6 columns]

# %%
box_office = pd.read_csv('../data/boxoffice.csv')

# %%
box_office
# Out:
#         rank                                 title studio  lifetime_gross  \
# 0          1          Star Wars: The Force Awakens     BV       936662225
# 1          2                                Avatar    Fox       760507625
# 2          3                         Black Panther     BV       700059566
# 3          4                Avengers: Infinity War     BV       678681680
# 4          5                               Titanic   Par.       659363944
# ...      ...                                   ...    ...             ...
# 15738  15739                           Dog Eat Dog    IFC              80
# 15739  15740                        Paranoid Girls    NaN              78
# 15740  15741  Confession of a Child of the Century  Cohen              74
# 15741  15742                            Storage 24  Magn.              72
# 15742  15743                           Zyzzyx Road   Reg.              30
#
#        year
# 0      2015
# 1      2009
# 2      2018
# 3      2018
# 4      1997
# ...     ...
# 15738  2009
# 15739  2015
# 15740  2015
# 15741  2013
# 15742  2006
#
# [15743 rows x 5 columns]

# %%
#Merge basic df and rating df
title_ratings_merged = title_basics_filtered.set_index('tconst').join(title_ratings.set_index('tconst'))
title_ratings_merged
# Out:
#           titleType                    primaryTitle  \
# tconst
# tt0000001     short                      Carmencita
# tt0000002     short          Le clown et ses chiens
# tt0000003     short                  Pauvre Pierrot
# tt0000004     short                     Un bon bock
# tt0000005     short                Blacksmith Scene
# ...             ...                             ...
# tt9916734     video                    Manca: Peleo
# tt9916754     movie  Chico Albuquerque - Revelações
# tt9916756     short        Pretty Pretty Black Girl
# tt9916764     short                              38
# tt9916856     short                        The Wind
#
#                             originalTitle  isAdult startYear endYear  \
# tconst
# tt0000001                      Carmencita        0      1894      \N
# tt0000002          Le clown et ses chiens        0      1892      \N
# tt0000003                  Pauvre Pierrot        0      1892      \N
# tt0000004                     Un bon bock        0      1892      \N
# tt0000005                Blacksmith Scene        0      1893      \N
# ...                                   ...      ...       ...     ...
# tt9916734                    Manca: Peleo        0      2018      \N
# tt9916754  Chico Albuquerque - Revelações        0      2013      \N
# tt9916756        Pretty Pretty Black Girl        0      2019      \N
# tt9916764                              38        0      2018      \N
# tt9916856                        The Wind        0      2015      \N
#
#           runtimeMinutes                    genres  averageRating  numVotes
# tconst
# tt0000001              1         Documentary,Short            5.6    1609.0
# tt0000002              5           Animation,Short            6.0     197.0
# tt0000003              4  Animation,Comedy,Romance            6.5    1287.0
# tt0000004             12           Animation,Short            6.1     121.0
# tt0000005              1              Comedy,Short            6.1    2052.0
# ...                  ...                       ...            ...       ...
# tt9916734             \N               Music,Short            NaN       NaN
# tt9916754             49               Documentary            NaN       NaN
# tt9916756             \N                     Short            NaN       NaN
# tt9916764             \N                     Short            NaN       NaN
# tt9916856             27                     Short            NaN       NaN
#
# [1948514 rows x 10 columns]

# %%
crew_merged = title_crew.set_index('tconst').join(title_basics.set_index('tconst'))
crew_merged
# Out:
#                      directors                        writers  titleType  \
# tconst
# tt0000001            nm0005690                             \N      short
# tt0000002            nm0721526                             \N      short
# tt0000003            nm0721526                             \N      short
# tt0000004            nm0721526                             \N      short
# tt0000005            nm0005690                             \N      short
# ...                        ...                            ...        ...
# tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377  tvEpisode
# tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377  tvEpisode
# tt9916852  nm5519375,nm5519454  nm6182221,nm1628284,nm2921377  tvEpisode
# tt9916856           nm10538645                      nm6951431      short
# tt9916880            nm0996406            nm1482639,nm2586970  tvEpisode
#
#                         primaryTitle              originalTitle  isAdult  \
# tconst
# tt0000001                 Carmencita                 Carmencita        0
# tt0000002     Le clown et ses chiens     Le clown et ses chiens        0
# tt0000003             Pauvre Pierrot             Pauvre Pierrot        0
# tt0000004                Un bon bock                Un bon bock        0
# tt0000005           Blacksmith Scene           Blacksmith Scene        0
# ...                              ...                        ...      ...
# tt9916848              Episode #3.17              Episode #3.17        0
# tt9916850              Episode #3.19              Episode #3.19        0
# tt9916852              Episode #3.20              Episode #3.20        0
# tt9916856                   The Wind                   The Wind        0
# tt9916880  Horrid Henry Knows It All  Horrid Henry Knows It All        0
#
#           startYear endYear runtimeMinutes                    genres
# tconst
# tt0000001      1894      \N              1         Documentary,Short
# tt0000002      1892      \N              5           Animation,Short
# tt0000003      1892      \N              4  Animation,Comedy,Romance
# tt0000004      1892      \N             12           Animation,Short
# tt0000005      1893      \N              1              Comedy,Short
# ...             ...     ...            ...                       ...
# tt9916848      2010      \N             \N       Action,Drama,Family
# tt9916850      2010      \N             \N       Action,Drama,Family
# tt9916852      2010      \N             \N       Action,Drama,Family
# tt9916856      2015      \N             27                     Short
# tt9916880      2014      \N             10   Animation,Comedy,Family
#
# [6751900 rows x 10 columns]

# %%
#merge name basics df and title crew
crew_merged_final = crew_merged.set_index('directors').join(name_basics.set_index('nconst'))
crew_merged_final
# Out:
#                                            writers titleType  \
# \N                                              \N     short
# \N                                              \N     short
# \N                                              \N     short
# \N                                              \N     short
# \N                                              \N     short
# ...                                            ...       ...
# nm9993708,nm2113498,nm9993709  nm9993708,nm9993709     short
# nm9993708,nm9993709            nm9993708,nm9993709     short
# nm9993708,nm9993709            nm3571226,nm3571315     short
# nm9993709                      nm9993708,nm9993709     short
# nm9993709,nm9993708            nm9993708,nm9993709     short
#
#                                                 primaryTitle  \
# \N                                         Barnet Horse Fair
# \N                                           Pompiers à Lyon
# \N                             The Terrible Railway Accident
# \N                             The Wandering Negro Minstrels
# \N                                                 Brittania
# ...                                                      ...
# nm9993708,nm2113498,nm9993709        Sound Mind: Evil People
# nm9993708,nm9993709             Sound Mind: Breaking Me Down
# nm9993708,nm9993709                  Lost Light Sound Hearts
# nm9993709                                     My Dear Arthur
# nm9993709,nm9993708                                       ID
#
#                                                originalTitle  isAdult  \
# \N                                         Barnet Horse Fair        0
# \N                                           Pompiers à Lyon        0
# \N                             The Terrible Railway Accident        0
# \N                             The Wandering Negro Minstrels        0
# \N                                                 Brittania        0
# ...                                                      ...      ...
# nm9993708,nm2113498,nm9993709        Sound Mind: Evil People        0
# nm9993708,nm9993709             Sound Mind: Breaking Me Down        0
# nm9993708,nm9993709                  Lost Light Sound Hearts        0
# nm9993709                                     My Dear Arthur        0
# nm9993709,nm9993708                                       ID        0
#
#                               startYear endYear runtimeMinutes  \
# \N                                 1896      \N             \N
# \N                                 1896      \N              1
# \N                                 1896      \N             \N
# \N                                 1896      \N             \N
# \N                                 1898      \N             \N
# ...                                 ...     ...            ...
# nm9993708,nm2113498,nm9993709      2020      \N             \N
# nm9993708,nm9993709                2020      \N              9
# nm9993708,nm9993709                2018      \N             \N
# nm9993709                          2015      \N              5
# nm9993709,nm9993708                2015      \N              5
#
#                                           genres primaryName birthYear  \
# \N                                         Short         NaN       NaN
# \N                             Documentary,Short         NaN       NaN
# \N                                         Short         NaN       NaN
# \N                                   Music,Short         NaN       NaN
# \N                                         Short         NaN       NaN
# ...                                          ...         ...       ...
# nm9993708,nm2113498,nm9993709     Short,Thriller         NaN       NaN
# nm9993708,nm9993709                  Drama,Short         NaN       NaN
# nm9993708,nm9993709                  Drama,Short         NaN       NaN
# nm9993709                           Horror,Short   Lu Bevins        \N
# nm9993709,nm9993708                        Short         NaN       NaN
#
#                               deathYear                primaryProfession  \
# \N                                  NaN                              NaN
# \N                                  NaN                              NaN
# \N                                  NaN                              NaN
# \N                                  NaN                              NaN
# \N                                  NaN                              NaN
# ...                                 ...                              ...
# nm9993708,nm2113498,nm9993709       NaN                              NaN
# nm9993708,nm9993709                 NaN                              NaN
# nm9993708,nm9993709                 NaN                              NaN
# nm9993709                            \N  director,writer,cinematographer
# nm9993709,nm9993708                 NaN                              NaN
#
#                                                             knownForTitles
# \N                                                                     NaN
# \N                                                                     NaN
# \N                                                                     NaN
# \N                                                                     NaN
# \N                                                                     NaN
# ...                                                                    ...
# nm9993708,nm2113498,nm9993709                                          NaN
# nm9993708,nm9993709                                                    NaN
# nm9993708,nm9993709                                                    NaN
# nm9993709                      tt11772858,tt11772904,tt11702702,tt11772940
# nm9993709,nm9993708                                                    NaN
#
# [6751900 rows x 14 columns]
